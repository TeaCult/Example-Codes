# %%
from IPython.display import HTML

input_form = """
<div style="background-color:gainsboro; border:solid black; width:300px; padding:20px;">
Variable Name: <input type="text" id="var_name" value="foo"><br>
Variable Value: <input type="text" id="var_value" value="bar"><br>
<button onclick="set_value()">Set Value</button>
</div>
"""

javascript = """
<script type="text/Javascript">
    function set_value(){
        var var_name = document.getElementById('var_name').value;
        var var_value = document.getElementById('var_value').value;
        var command = var_name + " = '" + var_value + "'";
        console.log("Executing Command: " + command);
        
        var kernel = IPython.notebook.kernel;
        kernel.execute(command);
    }
</script>
"""

HTML(input_form + javascript)
# Out:
# <div style="background-color:gainsboro; border:solid black; width:300px; padding:20px;">
# Variable Name: <input type="text" id="var_name" value="foo"><br>
# Variable Value: <input type="text" id="var_value" value="bar"><br>
# <button onclick="set_value()">Set Value</button>
# </div>
#
# <script type="text/Javascript">
#     function set_value(){
#         var var_name = document.getElementById('var_name').value;
#         var var_value = document.getElementById('var_value').value;
#         var command = var_name + " = '" + var_value + "'";
#         console.log("Executing Command: " + command);
#
#         var kernel = IPython.notebook.kernel;
#         kernel.execute(command);
#     }
# </script>

# %%
print(sadas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2e52fe678284> in <module>()
# ----> 1 print(sadas)
#
# NameError: name 'sadas' is not defined

# %%
HTML("""<html><head></head><body><div class="med" id="res" role="main"><div data-jibp="h" data-jiis="uc" id="topstuff"><style>.spell{font-size:16px}.spell_orig{font-size:154px}#mss p{margin:0;padding-top:5px}</style><div class="_cy" id="msg_box" style="display:none"><p class="card-section ps-sru"><span><span class="spell" id="srfm"></span>&nbsp;<a class="spell" id="srfl"></a><br></span><span id="sif"><span class="spell_orig" id="sifm"></span>&nbsp;<a class="spell_orig" id="sifl"></a><br></span></p></div></div><div data-jibp="h" data-jiis="uc" id="search"><style>._ogd{margin:0 3px 0 0;cursor:auto;float:left}</style><div data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QGgga"><!--a--><h2 class="hd">Search Results</h2><div data-async-context="query:ipython%20notebook%20HTML1" id="ires"><ol eid="27ucVo75L4GwswHGm57oCw" id="rso"><div class="srg"><div class="g"><!--m--><div class="rc" data-hveid="28"><h3 class="r"><a href="/url?sa=t&amp;rct=j&amp;q=&amp;esrc=s&amp;source=web&amp;cd=1&amp;ved=0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFggdMAA&amp;url=https%3A%2F%2Fipython.org%2Fipython-doc%2F1%2Finteractive%2Fnbconvert.html&amp;usg=AFQjCNEDB4rnIyVooMqxxZxAo7qZDnJw3A&amp;sig2=upzGoO77N_CIx_lrVhOgpA" onmousedown="return rwt(this,'','','','1','AFQjCNEDB4rnIyVooMqxxZxAo7qZDnJw3A','upzGoO77N_CIx_lrVhOgpA','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFggdMAA','','',event)" target="_blank" data-href="https://ipython.org/ipython-doc/1/interactive/nbconvert.html">Converting notebooks to other formats — IPython 1.2.1: An ...</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm">https://<b>ipython</b>.org/<b>ipython</b>-doc/1/interactive/nbconvert.html</cite><div class="action-menu ab_ctl"><a class="_Fmb ab_button" href="#" id="am-b0" aria-label="Result details" aria-expanded="false" aria-haspopup="true" role="button" jsaction="m.tdd;keydown:m.hbke;keypress:m.mskpe" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70Q7B0IHjAA"><span class="mn-dwn-arw"></span></a><div class="action-menu-panel ab_dropdown" role="menu" tabindex="-1" jsaction="keydown:m.hdke;mouseover:m.hdhne;mouseout:m.hdhue" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QqR8IHzAA"><ul><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="https://webcache.googleusercontent.com/search?q=cache:8M33ZV5ZBp4J:https://ipython.org/ipython-doc/1/interactive/nbconvert.html+&amp;cd=1&amp;hl=en&amp;ct=clnk&amp;gl=tr" onmousedown="return rwt(this,'','','','1','AFQjCNFewjq7we2TqhEzbGLsj-ZnvL1Wbw','Pk-WakDKMC2NhEe4kmIhzg','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QIAggMAA','','',event)" target="_blank">Cached</a></li></ul></div></div></div><span class="st"><span class="f">Sep 23, 2015 - </span>Newly added in the 1.0 release of <em>IPython</em> is the nbconvert tool, which allows you to convert an .ipynb <em>notebook</em> document file into various static&nbsp;...</span></div></div></div><!--n--></div><div class="g"><!--m--><div class="rc" data-hveid="34"><h3 class="r"><a href="http://ipython.org/notebook.html" onmousedown="return rwt(this,'','','','2','AFQjCNFqSFXAaOAhp8p4pLnX7_x4D_d7yg','zg6tJh6nUS9OeXSvwY1qFg','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFggjMAE','','',event)" target="_blank">The IPython Notebook — IPython</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm"><b>ipython</b>.org/<b>notebook</b>.html</cite><div class="action-menu ab_ctl"><a class="_Fmb ab_button" href="#" id="am-b1" aria-label="Result details" aria-expanded="false" aria-haspopup="true" role="button" jsaction="m.tdd;keydown:m.hbke;keypress:m.mskpe" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70Q7B0IJDAB"><span class="mn-dwn-arw"></span></a><div class="action-menu-panel ab_dropdown" role="menu" tabindex="-1" jsaction="keydown:m.hdke;mouseover:m.hdhne;mouseout:m.hdhue" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QqR8IJTAB"><ul><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="http://webcache.googleusercontent.com/search?q=cache:J266ZBPZlQAJ:ipython.org/notebook.html+&amp;cd=2&amp;hl=en&amp;ct=clnk&amp;gl=tr" onmousedown="return rwt(this,'','','','2','AFQjCNGBvQgo7q-z1fOsex983ZOpRaxCjg','V_QB158sC1Wg03YQqBqbPQ','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QIAgmMAE','','',event)" target="_blank">Cached</a></li><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="/search?newwindow=1&amp;q=related:ipython.org/notebook.html+ipython+notebook+HTML1&amp;tbo=1&amp;sa=X&amp;ved=0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QHwgnMAE">Similar</a></li></ul></div></div></div><span class="st">The <em>IPython Notebook</em> is an interactive computational environment, in which you can combine code execution, rich text, mathematics, plots and rich media, as&nbsp;...</span></div></div></div><!--n--></div><div class="g"><!--m--><div class="rc" data-hveid="40"><h3 class="r"><a href="https://ipython.org/ipython-doc/2/notebook/notebook.html" onmousedown="return rwt(this,'','','','3','AFQjCNExkODrYaGsBMsz2r9nA-TZ38XL7w','_nq9DTe8-aMLgxsY4ebikQ','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFggpMAI','','',event)" target="_blank">The IPython Notebook — IPython 2.4.2-maint documentation</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm">https://<b>ipython</b>.org/<b>ipython</b>-doc/2/<b>notebook</b>/<b>notebook</b>.html</cite><div class="action-menu ab_ctl"><a class="_Fmb ab_button" href="#" id="am-b2" aria-label="Result details" aria-expanded="false" aria-haspopup="true" role="button" jsaction="m.tdd;keydown:m.hbke;keypress:m.mskpe" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70Q7B0IKjAC"><span class="mn-dwn-arw"></span></a><div class="action-menu-panel ab_dropdown" role="menu" tabindex="-1" jsaction="keydown:m.hdke;mouseover:m.hdhne;mouseout:m.hdhue" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QqR8IKzAC"><ul><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="https://webcache.googleusercontent.com/search?q=cache:v7fQqe71FDMJ:https://ipython.org/ipython-doc/2/notebook/notebook.html+&amp;cd=3&amp;hl=en&amp;ct=clnk&amp;gl=tr" onmousedown="return rwt(this,'','','','3','AFQjCNE2mkY5zjcAPHIQwst3--MW2QiPwQ','-wdtPYAQabw2YW9j_-r3KQ','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QIAgsMAI','','',event)" target="_blank">Cached</a></li></ul></div></div></div><span class="st">The <em>IPython notebook</em> combines two components: ... For example, publication-<wbr>quality figures rendered by the matplotlib library, can be included inline.</span></div></div></div><!--n--></div><div class="g"><!--m--><div class="rc" data-hveid="45"><h3 class="r"><span class="_ogd b w xsm">[PDF]</span><a href="/url?sa=t&amp;rct=j&amp;q=&amp;esrc=s&amp;source=web&amp;cd=4&amp;ved=0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFgguMAM&amp;url=https%3A%2F%2Fasmeurer.github.io%2Fpython3-presentation%2Fpython3-presentation.pdf&amp;usg=AFQjCNG8hoqwLRtAdMDDPfV58KbgK_Oraw&amp;sig2=a9V7aIMCrS-HgPN_kOvKcg" onmousedown="return rwt(this,'','','','4','AFQjCNG8hoqwLRtAdMDDPfV58KbgK_Oraw','a9V7aIMCrS-HgPN_kOvKcg','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFgguMAM','','',event)" target="_blank" data-href="https://asmeurer.github.io/python3-presentation/python3-presentation.pdf">10 awesome features of Python that you can't use because ...</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm">https://asmeurer.github.io/python3-presentation/python3-presentation.pdf</cite><div class="action-menu ab_ctl"><a class="_Fmb ab_button" href="#" id="am-b3" aria-label="Result details" aria-expanded="false" aria-haspopup="true" role="button" jsaction="m.tdd;keydown:m.hbke;keypress:m.mskpe" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70Q7B0ILzAD"><span class="mn-dwn-arw"></span></a><div class="action-menu-panel ab_dropdown" role="menu" tabindex="-1" jsaction="keydown:m.hdke;mouseover:m.hdhne;mouseout:m.hdhue" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QqR8IMDAD"><ul><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="https://webcache.googleusercontent.com/search?q=cache:1If4Z9f28LoJ:https://asmeurer.github.io/python3-presentation/python3-presentation.pdf+&amp;cd=4&amp;hl=en&amp;ct=clnk&amp;gl=tr" onmousedown="return rwt(this,'','','','4','AFQjCNGUfmn0HGmDDFbG8G8fRdKmtYpSWQ','lERc9RA6qAoT6RTpy2cZlg','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QIAgxMAM','','',event)" target="_blank">Cached</a></li></ul></div></div></div><span class="st"><span class="f">May 31, 2014 - </span>http://asmeurer.github.io/python3-presentation/slides.<em>html#1</em>. 1/72 ...... Run <em>IPython notebook</em> (in Python 3) from IPython git checkout and open.</span></div></div></div><!--n--></div><div class="g"><!--m--><div class="rc" data-hveid="51"><h3 class="r"><a href="https://asmeurer.github.io/python3-presentation/slides.html" onmousedown="return rwt(this,'','','','5','AFQjCNFbOgP3XtxTyIAtMLjvYdlztMWaxg','Z1Ty8E2vaqVBv8aRLk1y-g','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFgg0MAQ','','',event)" target="_blank">10 awesome features of Python that you can't use because ...</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm">https://asmeurer.github.io/python3-presentation/slides.html</cite><div class="action-menu ab_ctl"><a class="_Fmb ab_button" href="#" id="am-b4" aria-label="Result details" aria-expanded="false" aria-haspopup="true" role="button" jsaction="m.tdd;keydown:m.hbke;keypress:m.mskpe" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70Q7B0INTAE"><span class="mn-dwn-arw"></span></a><div class="action-menu-panel ab_dropdown" role="menu" tabindex="-1" jsaction="keydown:m.hdke;mouseover:m.hdhne;mouseout:m.hdhue" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QqR8INjAE"><ul><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="https://webcache.googleusercontent.com/search?q=cache:A90fcSrBZ5sJ:https://asmeurer.github.io/python3-presentation/slides.html+&amp;cd=5&amp;hl=en&amp;ct=clnk&amp;gl=tr" onmousedown="return rwt(this,'','','','5','AFQjCNGjnC9GGPp5tv3DId3lcjZRZ_okOA','DjvAJpnScvfgvd-T6jZ_LQ','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QIAg3MAQ','','',event)" target="_blank">Cached</a></li></ul></div></div></div><span class="st">10 awesome features of Python that you can't use because you refuse to upgrade to Python 3. There is also a pdf version of these slides. 1 / 72&nbsp;...</span></div></div></div><!--n--></div><div class="g"><!--m--><div class="rc" data-hveid="56"><h3 class="r"><a href="/url?sa=t&amp;rct=j&amp;q=&amp;esrc=s&amp;source=web&amp;cd=6&amp;cad=rja&amp;uact=8&amp;ved=0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFgg5MAU&amp;url=https%3A%2F%2Fnews.ycombinator.com%2Fitem%3Fid%3D8918297&amp;usg=AFQjCNHByJt-2E4c4ujpRZ2Cxi8QkgDGpQ&amp;sig2=dPTfxdinaR7CTNovscFsqQ" onmousedown="return rwt(this,'','','','6','AFQjCNHByJt-2E4c4ujpRZ2Cxi8QkgDGpQ','dPTfxdinaR7CTNovscFsqQ','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFgg5MAU','','',event)" target="_blank" data-href="https://news.ycombinator.com/item?id=8918297">Show HN: Kronos Notebook – IPython as a Mac App ...</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm">https://news.ycombinator.com/item?id=8918297</cite></div><span class="st">There is a open source and free version of the <em>IPython notebook</em> as a OS X app, ... [0] http://ipython.org/notebook.<em>html [1</em>] http://www.kronosnotebook.com/haskell<wbr>&nbsp;...</span></div></div></div><!--n--></div><div class="g"><!--m--><div class="rc" data-hveid="58"><h3 class="r"><a href="http://www.academia.edu/19815227/Convert_IPython_Notebook_to_pdf_and_html_format_on_Mac_OS_X" onmousedown="return rwt(this,'','','','7','AFQjCNHAIVtidPxfzHTbVe5q64pW52yk6Q','ED4QC6sJoZtniXVrydXL5Q','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFgg7MAY','','',event)" target="_blank">Convert IPython Notebook to pdf and html format on Mac OS X</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm">www.academia.edu/.../Convert_<b>IPython</b>_<b>Notebook</b>_to_pdf_and_html_f...</cite><div class="action-menu ab_ctl"><a class="_Fmb ab_button" href="#" id="am-b6" aria-label="Result details" aria-expanded="false" aria-haspopup="true" role="button" jsaction="m.tdd;keydown:m.hbke;keypress:m.mskpe" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70Q7B0IPDAG"><span class="mn-dwn-arw"></span></a><div class="action-menu-panel ab_dropdown" role="menu" tabindex="-1" jsaction="keydown:m.hdke;mouseover:m.hdhne;mouseout:m.hdhue" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QqR8IPTAG"><ul><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="http://webcache.googleusercontent.com/search?q=cache:I1FfOiUgddMJ:www.academia.edu/19815227/Convert_IPython_Notebook_to_pdf_and_html_format_on_Mac_OS_X+&amp;cd=7&amp;hl=en&amp;ct=clnk&amp;gl=tr" onmousedown="return rwt(this,'','','','7','AFQjCNGqws2FP8lgZaRLmx2wfYacwcSIJw','ZfoYg98x6frOQ_Qwsjz4pQ','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QIAg-MAY','','',event)" target="_blank">Cached</a></li></ul></div></div></div><span class="st"><span class="f">Dec 24, 2015 - </span>Convert <em>IPython Notebook</em> to pdf and html format on Mac OS X ... documentation https://ipython.org/ipython-doc/1/interactive/nbconvert.<em>html 1</em>.</span></div></div></div><!--n--></div><div class="g"><!--m--><div class="rc" data-hveid="64"><h3 class="r"><a href="http://serialized.net/2014/09/ipython-notebook-storytelling/" onmousedown="return rwt(this,'','','','8','AFQjCNFaza_xVTMJKWuqvCmIuz0wiYVaTw','CfZ_YmxaiYcUHRE-oRzgog','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFghBMAc','','',event)" target="_blank">Telling Technology Stories with IPython Notebook ...</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm">serialized.net/2014/09/<b>ipython</b>-<b>notebook</b>-storytelling/</cite><div class="action-menu ab_ctl"><a class="_Fmb ab_button" href="#" id="am-b7" aria-label="Result details" aria-expanded="false" aria-haspopup="true" role="button" jsaction="m.tdd;keydown:m.hbke;keypress:m.mskpe" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70Q7B0IQjAH"><span class="mn-dwn-arw"></span></a><div class="action-menu-panel ab_dropdown" role="menu" tabindex="-1" jsaction="keydown:m.hdke;mouseover:m.hdhne;mouseout:m.hdhue" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QqR8IQzAH"><ul><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="http://webcache.googleusercontent.com/search?q=cache:i1BjQlx2jYQJ:serialized.net/2014/09/ipython-notebook-storytelling/+&amp;cd=8&amp;hl=en&amp;ct=clnk&amp;gl=tr" onmousedown="return rwt(this,'','','','8','AFQjCNHOhvXRsajBvOqyzYzGqAqEpCHfQQ','wEDHvzNBYYtFnKd8IBjh-A','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QIAhEMAc','','',event)" target="_blank">Cached</a></li><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="/search?newwindow=1&amp;q=related:serialized.net/2014/09/ipython-notebook-storytelling/+ipython+notebook+HTML1&amp;tbo=1&amp;sa=X&amp;ved=0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QHwhFMAc">Similar</a></li></ul></div></div></div><span class="st"><span class="f">Sep 2, 2014 - </span>The best way to see the slides is live, with a running <em>IPython Notebook</em>. You can get all the code (and the instructions to get started) in the talk's&nbsp;...</span></div></div></div><!--n--></div><div class="g"><!--m--><div class="rc" data-hveid="71"><h3 class="r"><a href="https://github.com/jrjohansson?tab=repositories" onmousedown="return rwt(this,'','','','9','AFQjCNHTadPWjtD_chSL-rqNK8svrFWIag','4PAPuzxOPD5exvCSXqSnYA','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFghIMAg','','',event)" target="_blank">jrjohansson (Robert Johansson) · GitHub</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm">https://github.com/jrjohansson?tab=repositories</cite><div class="action-menu ab_ctl"><a class="_Fmb ab_button" href="#" id="am-b8" aria-label="Result details" aria-expanded="false" aria-haspopup="true" role="button" jsaction="m.tdd;keydown:m.hbke;keypress:m.mskpe" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70Q7B0ISTAI"><span class="mn-dwn-arw"></span></a><div class="action-menu-panel ab_dropdown" role="menu" tabindex="-1" jsaction="keydown:m.hdke;mouseover:m.hdhne;mouseout:m.hdhue" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QqR8ISjAI"><ul><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="https://webcache.googleusercontent.com/search?q=cache:KS-gQb6oWBQJ:https://github.com/jrjohansson%3Ftab%3Drepositories+&amp;cd=9&amp;hl=en&amp;ct=clnk&amp;gl=tr" onmousedown="return rwt(this,'','','','9','AFQjCNGOOP6SIfPnLtjjDHj4uiLyD6e6gA','-aq0ryV-33YcRFFbsrdzQA','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QIAhLMAg','','',event)" target="_blank">Cached</a></li><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="/search?newwindow=1&amp;q=related:https://github.com/jrjohansson%3Ftab%3Drepositories+ipython+notebook+HTML1&amp;tbo=1&amp;sa=X&amp;ved=0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QHwhMMAg">Similar</a></li></ul></div></div></div><span class="st">ipynb-launcher. Script for starting and stopping <em>ipython notebooks</em> for a given list directories with notebooks, and for a given list of ipython interpreters.</span></div></div></div><!--n--></div><div class="g"><!--m--><div class="rc" data-hveid="77"><h3 class="r"><a href="https://github.com/thalesians" onmousedown="return rwt(this,'','','','10','AFQjCNEeAaYSFovy7x8JyYgNI2zLiaUqxA','KU2hWEiP-CLd_rWQV_1HGQ','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QFghOMAk','','',event)" target="_blank">Thalesians · GitHub</a></h3><div class="s"><div><div class="f kv _SWb" style="white-space:nowrap"><cite class="_Rm">https://github.com/thalesians</cite><div class="action-menu ab_ctl"><a class="_Fmb ab_button" href="#" id="am-b9" aria-label="Result details" aria-expanded="false" aria-haspopup="true" role="button" jsaction="m.tdd;keydown:m.hbke;keypress:m.mskpe" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70Q7B0ITzAJ"><span class="mn-dwn-arw"></span></a><div class="action-menu-panel ab_dropdown" role="menu" tabindex="-1" jsaction="keydown:m.hdke;mouseover:m.hdhne;mouseout:m.hdhue" data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QqR8IUDAJ"><ul><li class="action-menu-item ab_dropdownitem" role="menuitem"><a class="fl" href="https://webcache.googleusercontent.com/search?q=cache:N9kEOVvPofYJ:https://github.com/thalesians+&amp;cd=10&amp;hl=en&amp;ct=clnk&amp;gl=tr" onmousedown="return rwt(this,'','','','10','AFQjCNEec_fSh01MwWzjd1jYuX5Ev5JmUA','70gLcqokyY0kFGG_eIr6_w','0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QIAhRMAk','','',event)" target="_blank">Cached</a></li></ul></div></div></div><span class="st">... on Aug 6, 2015. <em>HTML 1</em> 82 ... A collection of <em>IPython notebooks</em> that feature Plotly graphs. Content moved to https://plot.ly/<em>ipython</em>-<em>notebooks</em>/. Updated on Jul<wbr>&nbsp;...</span></div></div></div><!--n--></div></div><hr class="rgsep"></ol></div><!--z--></div></div></div></body></html>""")
# Out:
# <html><head></head><body><div class="med" id="res" role="main"><div data-jibp="h" data-jiis="uc" id="topstuff"><style>.spell{font-size:16px}.spell_orig{font-size:154px}#mss p{margin:0;padding-top:5px}</style><div class="_cy" id="msg_box" style="display:none"><p class="card-section ps-sru"><span><span class="spell" id="srfm"></span>&nbsp;<a class="spell" id="srfl"></a><br></span><span id="sif"><span class="spell_orig" id="sifm"></span>&nbsp;<a class="spell_orig" id="sifl"></a><br></span></p></div></div><div data-jibp="h" data-jiis="uc" id="search"><style>._ogd{margin:0 3px 0 0;cursor:auto;float:left}</style><div data-ved="0ahUKEwjO0vmLkbPKAhUB2CwKHcaNB70QGgga"><!--a--><h2 class="hd">Search Results</h2><div data-async-context="query:ipython%20notebook%20HTML1" id="ires"><ol eid="27ucVo75L4GwswHGm57oCw" id="rso"><div class="srg"><div class="g"><!--m--><div class="rc" data-hveid="28"><h3 class="r"><a href="/url?sa=t&amp;rct=j&amp;q=&amp;esrc=s&amp;source=web&amp;cd=1&amp;ved=0ahUKEwjO0vm
# ...

# %%
HTML("""<html lang="en">
	<head>
		<title>three.js webgl - scene animation</title>
		<meta charset="utf-8">
		<meta name="viewport" content="width=device-width, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0">
		<style>
			body {
				color: #000;
				font-family:Monospace;
				font-size:13px;
				text-align:center;

				background-color: #fff;
				margin: 0px;
				overflow: hidden;
			}

			#info {
				position: absolute;
				top: 0px; width: 100%;
				padding: 5px;
			}

			a {
				color: #0af;
			}

			#stats { position: absolute; top:0; left: 0 }
			#stats #fps { background: transparent !important }
			#stats #fps #fpsText { color: #777 !important }
			#stats #fps #fpsGraph { display: none }
		</style>
	</head>

	<body>

		<div id="container"></div>

		<div id="info">
		<a href="http://threejs.org" target="_blank">three.js</a> webgl - scene animation - <a href="https://clara.io/view/96106133-2e99-40cf-8abd-64defd153e61">Three Gears Scene</a> courtesy of David Sarno</div>

		<script src="../build/three.min.js"></script>

		<script src="js/Detector.js"></script>
		<script src="js/libs/stats.min.js"></script>

		<script>

			var SCREEN_WIDTH = window.innerWidth;
			var SCREEN_HEIGHT = window.innerHeight;
			var FLOOR = -250;

			var container,stats;

			var camera, scene, sceneAnimationClip;
			var renderer;

			var mesh, helper;

			var mixer;
		
			var mouseX = 0, mouseY = 0;

			var windowHalfX = window.innerWidth / 2;
			var windowHalfY = window.innerHeight / 2;

			var clock = new THREE.Clock();

			document.addEventListener( 'mousemove', onDocumentMouseMove, false );

			init();
			animate();

			function init() {

				container = document.getElementById( 'container' );

				camera = new THREE.PerspectiveCamera( 30, SCREEN_WIDTH / SCREEN_HEIGHT, 1, 10000 );
				camera.position.z = 150;

				scene = new THREE.Scene();

				scene.fog = new THREE.Fog( 0xffffff, 2000, 10000 );

				//scene.add( camera );

				// GROUND

				var geometry = new THREE.PlaneBufferGeometry( 16000, 16000 );
				var material = new THREE.MeshPhongMaterial( { emissive: 0x000000 } );

				var ground = new THREE.Mesh( geometry, material );
				ground.position.set( 0, FLOOR, 0 );
				ground.rotation.x = -Math.PI/2;
				/*scene.add( ground );*/

				ground.receiveShadow = true;


				// RENDERER

				renderer = new THREE.WebGLRenderer( { antialias: true } );
				renderer.setClearColor( scene.fog.color );
				renderer.setPixelRatio( window.devicePixelRatio );
				renderer.setSize( SCREEN_WIDTH, SCREEN_HEIGHT );
				renderer.domElement.style.position = "relative";

				container.appendChild( renderer.domElement );

				renderer.gammaInput = true;
				renderer.gammaOutput = true;

				renderer.shadowMap.enabled = true;


				// STATS

				stats = new Stats();
				container.appendChild( stats.domElement );

				//

				var loader = new THREE.ObjectLoader();
				loader.load( "models/json/scene-animation.json", function ( loadedScene ) {

					sceneAnimationClip = loadedScene.animations[0];
					scene = loadedScene;
					scene.add( camera );
					scene.fog = new THREE.Fog( 0xffffff, 2000, 10000 );
		
					mixer = new THREE.AnimationMixer( scene );
			
					mixer.addAction( new THREE.AnimationAction( sceneAnimationClip ) );

				} );

				window.addEventListener( 'resize', onWindowResize, false );

			}

			function onWindowResize() {

				windowHalfX = window.innerWidth / 2;
				windowHalfY = window.innerHeight / 2;

				camera.aspect = window.innerWidth / window.innerHeight;
				camera.updateProjectionMatrix();

				renderer.setSize( window.innerWidth, window.innerHeight );

			}


			function onDocumentMouseMove( event ) {

				mouseX = ( event.clientX - windowHalfX );
				mouseY = ( event.clientY - windowHalfY );

			}

			//

			function animate() {

				requestAnimationFrame( animate );

				render();
				stats.update();

			}

			function render() {

				var delta = 0.75 * clock.getDelta();

				camera.position.x += ( mouseX - camera.position.x ) * .05;
				camera.position.y = THREE.Math.clamp( camera.position.y + ( - mouseY - camera.position.y ) * .05, 0, 1000 );

				camera.lookAt( scene.position );

				if( mixer ) {
					//console.log( "updating mixer by " + delta );
					mixer.update( delta );
				}

				renderer.render( scene, camera );

			}

		</script>

	</body>
</html>""")
# Out:
# <html lang="en">
# 	<head>
# 		<title>three.js webgl - scene animation</title>
# 		<meta charset="utf-8">
# 		<meta name="viewport" content="width=device-width, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0">
# 		<style>
# 			body {
# 				color: #000;
# 				font-family:Monospace;
# 				font-size:13px;
# 				text-align:center;
#
# 				background-color: #fff;
# 				margin: 0px;
# 				overflow: hidden;
# 			}
#
# 			#info {
# 				position: absolute;
# 				top: 0px; width: 100%;
# 				padding: 5px;
# 			}
#
# 			a {
# 				color: #0af;
# 			}
#
# 			#stats { position: absolute; top:0; left: 0 }
# 			#stats #fps { background: transparent !important }
# 			#stats #fps #fpsText { color: #777 !important }
# 			#stats #fps #fpsGraph { display: none }
# 		</style>
# 	</head>
#
# 	<body>
#
# 		<div id="container"></div>
#
# 		<div id="info">
# ...
